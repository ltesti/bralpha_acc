# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys

sys.path.append('../')
import bralpha_acc as bac

# %%
cii = bac.cii_data("class_ii_table_cardelli.csv")
# Out:
# /private/var/mobile/Containers/Shared/AppGroup/9BC32FF5-6A5F-474F-A57A-5AD98BBCD7D1/File Provider Storage/Repositories/bralpha_acc/examples/../bralpha_acc/lline.py:34: RuntimeWarning: invalid value encountered in log10
#   Llinem[ng] = np.log10(((f[ng]-ef[ng]) * 1.e-17 * 4 * np.pi * (pc_to_m(d_pc[ng]) ** 2)) / lsun)

# %%
cii.plot_ratio(plot='Pfg')

# %%
fig,ax = plt.subplots(1,2,figsize=(14,7))
ax[0].errorbar(cii.data['Lstar'],cii.lbra,yerr=[(cii.lbra-cii.lbram),(cii.lbrap-cii.lbra)],fmt='o',color='red')   
ax[0].errorbar(cii.data['Lstar'],cii.lpfg,yerr=[(cii.lpfg-cii.lpfgm),(cii.lpfgp-cii.lpfg)],fmt='o',color='green')   
ax[0].errorbar(cii.data['Lstar'],cii.lbrg,yerr=[(cii.lbrg-cii.lbrgm),(cii.lbrgp-cii.lbrg)],fmt='o',color='cyan')   
ax[0].set_ylim(-6,0)
ax[1].errorbar(cii.data['Lstar'],cii.lbra,yerr=cii.elbra,fmt='o',color='red')   
ax[1].errorbar(cii.data['Lstar'],cii.lpfg,yerr=cii.elpfg,fmt='o',color='green')   
ax[1].errorbar(cii.data['Lstar'],cii.lbrg,yerr=cii.elbrg,fmt='o',color='cyan')   
ax[1].set_ylim(-6,0)
cii.elpfg
# Out:
# array([ 0.09113594,  1.15638113,  0.22384054,  0.42938005,  0.07208568,
#         0.06560566,  0.04001905,  0.07547728,  0.06204207,  0.06095361,
#        -0.        ,  0.02326578,  0.20547266,  0.0980665 ,  0.05345163,
#         0.02311834,  0.        ,  0.11428802,  0.21714724,  0.13217658,
#         0.03897515,  0.03840699,  0.19000384,  0.30066541,  0.04136138])

# %%
plt.errorbar(cii.Lacc_Fairlamb,cii.lbrg,yerr=[(cii.lbrg-cii.lbrgm),(cii.lbrgp-cii.lbrg)],fmt='o', color='blue')
# Out:
# <ErrorbarContainer object of 3 artists>
