# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys

sys.path.append('../')
from bralpha_acc.io import read_table

# %%
d_II = read_table("class_ii_table_original_rv31.csv")
d_I = read_table("class_i_table_ratio55_rv55.csv", preset='ClassI')

# %%
d_I['Fbra']/d_I['Fbrg']
# Out:
# array([11.46235561, 16.37688162, 26.08352244,  8.81699526, 13.91949055,
#         9.56957145,  9.89588878,  8.04556212,  4.55897585,  5.29457045,
#         5.12582233,  2.07943317,  1.14913039,  2.00318288,  2.300608  ,
#         1.35075292,  9.76799106])

# %%
d[d.columns[0]]
# Out:
# 0      hd163296
# 1     j162816.7
# 2     j162755.6
# 3     j162617.1
# 4     j162556.1
# 5         bptau
# 6         citau
# 7         cwtau
# 8       LkHa198
# 9         BD+61
# 10      Elias1a
# 11      Elias1b
# 12        ABAur
# 13      V380Ori
# 14      HD37490
# 15    HD259431a
# 16    HD259431b
# 17         RMon
# 18      HD53367
# 19       MWC297
# 20     HD200775
# 21      LkHa234
# 22        BD+46
# 23      MWC1080
# Name: Name, dtype: object
